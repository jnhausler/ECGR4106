# %% [markdown]
# Import pre-trained models

# %%
from torchvision import models

# %% [markdown]
# All the models imported

# %%
#dir(models)

# %% [markdown]
# Create an instance of the 101-layer CNN ResNet

# %%
resnet = models.resnet101(pretrained=True)

# %%
#resnet

# %% [markdown]
# Define a preprocessing function using the tranform function from torch vision to adjust picture to ResNets necessary parameters

# %%
from torchvision import transforms
preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225]
        )])

# %% [markdown]
# Import first image

# %%
from PIL import Image
img = Image.open("/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 1/cat_eyes_closed.jpg")

# %% [markdown]
# Show image

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7FCE9CD30090>

# %% [markdown]
# Preprocess the first image

# %%
img_t = preprocess(img)

# %% [markdown]
# Reshape, crop, and normalize the input tensor in a way that the network
# expects

# %%
import torch
batch_t = torch.unsqueeze(img_t, 0)

# %% [markdown]
# Put the network in eval mode

# %%
resnet.eval();

# %% [markdown]
# Inference

# %%
out = resnet(batch_t)

# %% [markdown]
# Load the file containing the 1000 labels from ResNet

# %%
with open('/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 1/imagenet_classes.txt') as f:
    labels = [line.strip() for line in f.readlines()]

# %% [markdown]
# Output the maximum value in the tensor and the indices where
# that maximum value occurred

# %%
_, index = torch.max(out, 1)

# %% [markdown]
# Show the prediction and the level of confidence

# %%
percentage = torch.nn.functional.softmax(out, dim=1)[0] * 100
labels[index[0]], percentage[index[0]].item()
# Out:
# ('tabby, tabby cat', 69.10633087158203)

# %% [markdown]
# Show the top 5 predictions and their level of confidence

# %%
_, indices = torch.sort(out, descending=True)
[(labels[idx], percentage[idx].item()) for idx in indices[0][:5]]
# Out:
# [('tabby, tabby cat', 69.10633087158203),
#  ('tiger cat', 14.811970710754395),
#  ('Egyptian cat', 11.066707611083984),
#  ('lynx, catamount', 4.245384693145752),
#  ('grey fox, gray fox, Urocyon cinereoargenteus', 0.12432130426168442)]

# %% [markdown]
# Import second figure of cat with eyes open

# %%
img2 = Image.open("/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 1/kitten_eyes_open.jpg")

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=318x159 at 0x7FCE9B2619D0>

# %% [markdown]
# Process second image of kitten

# %%
img_t2 = preprocess(img2)

# %% [markdown]
# Reshape, crop, and normalize the input tensor in a way that the network expects

# %%
batch_t2 = torch.unsqueeze(img_t2, 0)

# %% [markdown]
# Inference second image

# %%
out2 = resnet(batch_t2)

# %% [markdown]
# Output the maximum value in the tensor and the indices where that maximum value occurred

# %%
_, index2 = torch.max(out2, 1)

# %% [markdown]
# Convert the confidence to percentage

# %%
percentage2 = torch.nn.functional.softmax(out2, dim=1)[0] * 100

# %% [markdown]
# Show the top 5 predictions and their level of confidence

# %%
_, indices2 = torch.sort(out2, descending=True)
[(labels[idx], percentage2[idx].item()) for idx in indices2[0][:5]]
# Out:
# [('tabby, tabby cat', 72.07164764404297),
#  ('Egyptian cat', 14.044600486755371),
#  ('tiger cat', 7.870572090148926),
#  ('lynx, catamount', 4.940651893615723),
#  ('plastic bag', 0.07008504122495651)]

# %% [markdown]
# Third Image of a green smoothie

# %%
img3 = Image.open("/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 1/green_smoothie.jpg")
img3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x7FCE9B2516D0>

# %% [markdown]
# Preprocess third image

# %%
img_t3 = preprocess(img3)

# %% [markdown]
# Reshape, crop, and normalize the input tensor in a way that the network expects

# %%
batch_t3 = torch.unsqueeze(img_t3, 0)

# %% [markdown]
# Inference third image

# %%
out3 = resnet(batch_t3)

# %% [markdown]
# Output the maximum value in the tensor and the indices where that maximum value occurred

# %%
_, index3 = torch.max(out3, 1)

# %% [markdown]
# Convert the confidence to percentage

# %%
percentage3 = torch.nn.functional.softmax(out3, dim=1)[0] * 100

# %% [markdown]
# Show the top 5 predictions and their level of confidence

# %%
_, indices3 = torch.sort(out3, descending=True)
[(labels[idx], percentage3[idx].item()) for idx in indices3[0][:5]]
# Out:
# [('eggnog', 37.40727996826172),
#  ('cucumber, cuke', 14.084015846252441),
#  ('guacamole', 7.775632858276367),
#  ('lemon', 6.996551990509033),
#  ('plate', 6.543576717376709)]

# %% [markdown]
# Fourth Image of succulent plants

# %%
img4 = Image.open("/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 1/succulents.jpg")
img4
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x7FCE9B248BD0>

# %% [markdown]
# Preprocess fourth image

# %%
img_t4 = preprocess(img4)

# %% [markdown]
# Reshape, crop, and normalize the input tensor in a way that the network expects

# %%
batch_t4 = torch.unsqueeze(img_t4, 0)

# %% [markdown]
# Inference fourth image

# %%
out4 = resnet(batch_t4)

# %% [markdown]
# Output the maximum value in the tensor and the indices where that maximum value occurred

# %%
_, index4 = torch.max(out4, 1)

# %% [markdown]
# Convert the confidence to percentage

# %%
percentage4 = torch.nn.functional.softmax(out4, dim=1)[0] * 100

# %% [markdown]
# Show the top 5 predictions and their level of confidence

# %%
_, indices4 = torch.sort(out4, descending=True)
[(labels[idx], percentage4[idx].item()) for idx in indices4[0][:5]]
# Out:
# [('artichoke, globe artichoke', 28.20506477355957),
#  ('hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa',
#   23.540267944335938),
#  ('coil, spiral, volute, whorl, helix', 16.23322296142578),
#  ('earthstar', 6.134302139282227),
#  ('confectionery, confectionary, candy store', 4.0310845375061035)]

# %% [markdown]
# Fifth Image of a rottweiler

# %%
img5 = Image.open("/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 1/rottweiler.jpg")
img5
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7FCE9CCB6C10>

# %% [markdown]
# Preprocess fifth image

# %%
img_t5 = preprocess(img5)

# %% [markdown]
# Reshape, crop, and normalize the input tensor in a way that the network expects

# %%
batch_t5 = torch.unsqueeze(img_t5, 0)

# %% [markdown]
# Inference fifth image

# %%
out5 = resnet(batch_t5)

# %% [markdown]
# Output the maximum value in the tensor and the indices where that maximum value occurred

# %%
_, index5 = torch.max(out5, 1)

# %% [markdown]
# Convert the confidence to percentage

# %%
percentage5 = torch.nn.functional.softmax(out5, dim=1)[0] * 100

# %% [markdown]
# Show the top 5 predictions and their level of confidence

# %%
_, indices5 = torch.sort(out5, descending=True)
[(labels[idx], percentage5[idx].item()) for idx in indices5[0][:5]]
# Out:
# [('Rottweiler', 99.41569519042969),
#  ('black-and-tan coonhound', 0.21492648124694824),
#  ('Doberman, Doberman pinscher', 0.11537366360425949),
#  ('Appenzeller', 0.04772539809346199),
#  ('miniature pinscher', 0.03449175879359245)]

# %% [markdown]
# **PROBLEM 2**

# %% [markdown]
# Define a ResNetGenerator class

# %%
import torch
import torch.nn as nn

class ResNetBlock(nn.Module): # <1>

    def __init__(self, dim):
        super(ResNetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim)

    def build_conv_block(self, dim):
        conv_block = []

        conv_block += [nn.ReflectionPad2d(1)]

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=0, bias=True),
                       nn.InstanceNorm2d(dim),
                       nn.ReLU(True)]

        conv_block += [nn.ReflectionPad2d(1)]

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=0, bias=True),
                       nn.InstanceNorm2d(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x) # <2>
        return out


class ResNetGenerator(nn.Module):

    def __init__(self, input_nc=3, output_nc=3, ngf=64, n_blocks=9): # <3> 

        assert(n_blocks >= 0)
        super(ResNetGenerator, self).__init__()

        self.input_nc = input_nc
        self.output_nc = output_nc
        self.ngf = ngf

        model = [nn.ReflectionPad2d(3),
                 nn.Conv2d(input_nc, ngf, kernel_size=7, padding=0, bias=True),
                 nn.InstanceNorm2d(ngf),
                 nn.ReLU(True)]

        n_downsampling = 2
        for i in range(n_downsampling):
            mult = 2**i
            model += [nn.Conv2d(ngf * mult, ngf * mult * 2, kernel_size=3,
                                stride=2, padding=1, bias=True),
                      nn.InstanceNorm2d(ngf * mult * 2),
                      nn.ReLU(True)]

        mult = 2**n_downsampling
        for i in range(n_blocks):
            model += [ResNetBlock(ngf * mult)]

        for i in range(n_downsampling):
            mult = 2**(n_downsampling - i)
            model += [nn.ConvTranspose2d(ngf * mult, int(ngf * mult / 2),
                                         kernel_size=3, stride=2,
                                         padding=1, output_padding=1,
                                         bias=True),
                      nn.InstanceNorm2d(int(ngf * mult / 2)),
                      nn.ReLU(True)]

        model += [nn.ReflectionPad2d(3)]
        model += [nn.Conv2d(ngf, output_nc, kernel_size=7, padding=0)]
        model += [nn.Tanh()]

        self.model = nn.Sequential(*model)

    def forward(self, input): # <3>
        return self.model(input)

# %% [markdown]
# Instantiate ResNetGenerator class with default parameters

# %%
netG = ResNetGenerator()

# %% [markdown]
# Run a generator model that has been pretrained on the horse2zebra dataset

# %%
model_path = '/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 2/horse2zebra_0.4.0.pth'
model_data = torch.load(model_path)
netG.load_state_dict(model_data)
# Out:
# <All keys matched successfully>

# %% [markdown]
# Put the network into eval mode

# %%
netG.eval();

# %% [markdown]
# Define preprocess tranformations for this network

# %%
preprocess2 = transforms.Compose([transforms.Resize(256),
                                 transforms.ToTensor()])

# %% [markdown]
# Load first horse image

# %%
img2_1 = Image.open("/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 2/horse1.jpg")
img2_1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=353x143 at 0x7FCE9B1EE210>

# %% [markdown]
# Preprocess image and shape variable

# %%
img_t2_1 = preprocess2(img2_1)
batch_t2_1 = torch.unsqueeze(img_t2_1, 0)

# %% [markdown]
# Output of the generator

# %%
batch_out2_1 = netG(batch_t2_1)

# %% [markdown]
# Convert output back to an image

# %%
out_t2_1 = (batch_out2_1.data.squeeze() + 1.0) / 2.0
out_img2_1 = transforms.ToPILImage()(out_t2_1)
out_img2_1
# Out:
# <PIL.Image.Image image mode=RGB size=632x256 at 0x7FCE9B1EECD0>

# %% [markdown]
# Load second horse image

# %%
img2_2 = Image.open("/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 2/horse2.jpg")
img2_2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x168 at 0x7FCE9B248110>

# %% [markdown]
# Preprocess image and shape variable

# %%
img_t2_2 = preprocess2(img2_2)
batch_t2_2 = torch.unsqueeze(img_t2_2, 0)

# %% [markdown]
# Output of the generator

# %%
batch_out2_2 = netG(batch_t2_2)

# %% [markdown]
# Convert output back to an image

# %%
out_t2_2 = (batch_out2_2.data.squeeze() + 1.0) / 2.0
out_img2_2 = transforms.ToPILImage()(out_t2_2)
out_img2_2
# Out:
# <PIL.Image.Image image mode=RGB size=456x256 at 0x7FCE9B1F95D0>

# %% [markdown]
# Third horse image

# %%
img2_3 = Image.open("/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 2/horse3.jpg")
img2_3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7FCE9B1EE510>

# %% [markdown]
# Preprocess image and shape variable

# %%
img_t2_3 = preprocess2(img2_3)
batch_t2_3 = torch.unsqueeze(img_t2_3, 0)

# %% [markdown]
# Output of the generator

# %%
batch_out2_3 = netG(batch_t2_3)

# %% [markdown]
# Convert output back to an image

# %%
out_t2_3 = (batch_out2_3.data.squeeze() + 1.0) / 2.0
out_img2_3 = transforms.ToPILImage()(out_t2_3)
out_img2_3
# Out:
# <PIL.Image.Image image mode=RGB size=384x256 at 0x7FCE9AE89AD0>

# %% [markdown]
# Fourth Horse Image

# %%
img2_4 = Image.open("/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 2/horse4.jpg")
img2_4
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7FCE9B2618D0>

# %% [markdown]
# Preprocess image and shape variable

# %%
img_t2_4 = preprocess2(img2_4)
batch_t2_4 = torch.unsqueeze(img_t2_4, 0)

# %% [markdown]
# Output of the generator

# %%
batch_out2_4 = netG(batch_t2_4)

# %% [markdown]
# Convert output back to an image

# %%
out_t2_4 = (batch_out2_4.data.squeeze() + 1.0) / 2.0
out_img2_4 = transforms.ToPILImage()(out_t2_4)
out_img2_4
# Out:
# <PIL.Image.Image image mode=RGB size=384x256 at 0x7FCE9B251510>

# %% [markdown]
# Fifth Horse Image

# %%
img2_5 = Image.open("/content/drive/MyDrive/Colab Notebooks/Homework 0/hw0_data/Problem 2/horse5.jpg")
img2_5
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7FCE9B1F98D0>

# %% [markdown]
# Preprocess image and shape variable

# %%
img_t2_5 = preprocess2(img2_5)
batch_t2_5 = torch.unsqueeze(img_t2_5, 0)

# %% [markdown]
# Output of the generator

# %%
batch_out2_5 = netG(batch_t2_5)

# %% [markdown]
# Convert output back to an image

# %%
out_t2_5 = (batch_out2_5.data.squeeze() + 1.0) / 2.0
out_img2_5 = transforms.ToPILImage()(out_t2_5)
out_img2_5
# Out:
# <PIL.Image.Image image mode=RGB size=460x256 at 0x7FCE9B281590>

# %% [markdown]
# **PROBLEM 3**

# %% [markdown]
# Output the computational complexity and number of parameters of the ResNet 101 network used in problem 1

# %%
import torchvision.models as models
from ptflops import get_model_complexity_info

with torch.cuda.device(0):
  macs, params = get_model_complexity_info(resnet, (3, 224, 224), as_strings=True,
                                           print_per_layer_stat=True, verbose=True)
  print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
  print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# ...
# ResNet(
#   44.549 M, 100.000% Params, 7.85 GMac, 100.000% MACs,
#   (conv1): Conv2d(0.009 M, 0.021% Params, 0.118 GMac, 1.503% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(0.0 M, 0.000% Params, 0.002 GMac, 0.020% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(0.0 M, 0.000% Params, 0.001 GMac, 0.010% MACs, inplace=True)
#   (maxpool): MaxPool2d(0.0 M, 0.000% Params, 0.001 GMac, 0.010% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     0.216 M, 0.484% Params, 0.68 GMac, 8.668% MACs,
#     (0): Bottleneck(
#       0.075 M, 0.168% Params, 0.236 GMac, 3.012% MACs,
#       (conv1): Conv2d(0.004 M, 0.009% Params, 0.013 GMac, 0.164% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(0.0 M, 0.000% Params, 0.0 GMac, 0.005% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# Output the computational complexity and number of parameters for the ResNetGen network used in problem 2

# %%
with torch.cuda.device(0):
  macs, params = get_model_complexity_info(netG, (3, 256, 256), as_strings=True,
                                           print_per_layer_stat=True, verbose=True)
  print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
  print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# ...
# ResNetGenerator(
#   11.378 M, 100.000% Params, 56.888 GMac, 100.000% MACs,
#   (model): Sequential(
#     11.378 M, 100.000% Params, 56.888 GMac, 100.000% MACs,
#     (0): ReflectionPad2d(0.0 M, 0.000% Params, 0.0 GMac, 0.000% MACs, (3, 3, 3, 3))
#     (1): Conv2d(0.009 M, 0.083% Params, 0.621 GMac, 1.091% MACs, 3, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): InstanceNorm2d(0.0 M, 0.000% Params, 0.004 GMac, 0.007% MACs, 64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (3): ReLU(0.0 M, 0.000% Params, 0.004 GMac, 0.007% MACs, inplace=True)
#     (4): Conv2d(0.074 M, 0.649% Params, 1.21 GMac, 2.127% MACs, 64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): InstanceNorm2d(0.0 M, 0.000% Params, 0.002 GMac, 0.004% MACs, 128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (6): ReLU(0.0 M, 0.000% Params, 0.002 GMac, 0.004% MACs, inplace=True)
# ...

# %% [markdown]
# **PROBLEM 4**

# %% [markdown]
# Load MobileNet Model

# %%
mobilenet = torch.hub.load('pytorch/vision:v0.10.0', 'mobilenet_v2', pretrained=True);
mobilenet.eval();
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0

# %% [markdown]
# First Image Output

# %%
out2_1 = mobilenet(batch_t)

# %% [markdown]
# Output the maximum value in the tensor and the indices where
# that maximum value occurred

# %%
_, index2_1 = torch.max(out2_1, 1)

# %% [markdown]
# Show the prediction and the level of confidence

# %%
percentage2_1 = torch.nn.functional.softmax(out2_1, dim=1)[0] * 100

# %% [markdown]
# Show the top 5 predictions and their level of confidence

# %%
_, indices2_1 = torch.sort(out2_1, descending=True)
[(labels[idx], percentage2_1[idx].item()) for idx in indices2_1[0][:5]]
# Out:
# [('tabby, tabby cat', 68.09132385253906),
#  ('Egyptian cat', 25.689468383789062),
#  ('tiger cat', 5.001677989959717),
#  ('lynx, catamount', 0.8037791848182678),
#  ('snow leopard, ounce, Panthera uncia', 0.0800790935754776)]

# %% [markdown]
# Second Image Output

# %%
out2_2 = mobilenet(batch_t2)

# %% [markdown]
# Output the maximum value in the tensor and the indices where
# that maximum value occurred

# %%
_, index2_2 = torch.max(out2_2, 1)

# %% [markdown]
# Show the prediction and the level of confidence

# %%
percentage2_2 = torch.nn.functional.softmax(out2_2, dim=1)[0] * 100

# %% [markdown]
# Show the top 5 predictions and their level of confidence

# %%
_, indices2_2 = torch.sort(out2_2, descending=True)
[(labels[idx], percentage2_2[idx].item()) for idx in indices2_2[0][:5]]
# Out:
# [('tabby, tabby cat', 79.24430084228516),
#  ('Egyptian cat', 9.944387435913086),
#  ('tiger cat', 8.85935115814209),
#  ('lynx, catamount', 1.3299301862716675),
#  ('tiger, Panthera tigris', 0.15873363614082336)]

# %% [markdown]
# Third Image Output

# %%
out2_3 = mobilenet(batch_t3)

# %% [markdown]
# Output the maximum value in the tensor and the indices where
# that maximum value occurred

# %%
_, index2_3 = torch.max(out2_3, 1)

# %% [markdown]
# Show the prediction and the level of confidence

# %%
percentage2_3 = torch.nn.functional.softmax(out2_3, dim=1)[0] * 100

# %% [markdown]
# Show the top 5 predictions and their level of confidence

# %%
_, indices2_3 = torch.sort(out2_3, descending=True)
[(labels[idx], percentage2_3[idx].item()) for idx in indices2_3[0][:5]]
# Out:
# [('eggnog', 78.78779602050781),
#  ('head cabbage', 4.735452651977539),
#  ('lemon', 2.0320985317230225),
#  ('guacamole', 1.8342362642288208),
#  ('strawberry', 1.8028550148010254)]

# %% [markdown]
# Fourth Image Output

# %%
out2_4 = mobilenet(batch_t4)

# %% [markdown]
# Output the maximum value in the tensor and the indices where
# that maximum value occurred

# %%
_, index2_4 = torch.max(out2_4, 1)

# %% [markdown]
# Show the prediction and the level of confidence

# %%
percentage2_4 = torch.nn.functional.softmax(out2_4, dim=1)[0] * 100

# %% [markdown]
# Show the top 5 predictions and their level of confidence

# %%
_, indices2_4 = torch.sort(out2_4, descending=True)
[(labels[idx], percentage2_4[idx].item()) for idx in indices2_4[0][:5]]
# Out:
# [('artichoke, globe artichoke', 67.40802764892578),
#  ('coil, spiral, volute, whorl, helix', 14.546343803405762),
#  ('custard apple', 5.411108016967773),
#  ('confectionery, confectionary, candy store', 3.8309950828552246),
#  ('grocery store, grocery, food market, market', 1.4279181957244873)]

# %% [markdown]
# Fifth Image Output

# %%
out2_5 = mobilenet(batch_t5)

# %% [markdown]
# Output the maximum value in the tensor and the indices where
# that maximum value occurred

# %%
_, index2_5 = torch.max(out2_5, 1)

# %% [markdown]
# Show the prediction and the level of confidence

# %%
percentage2_5 = torch.nn.functional.softmax(out2_5, dim=1)[0] * 100

# %% [markdown]
# Show the top 5 predictions and their level of confidence

# %%
_, indices2_5 = torch.sort(out2_5, descending=True)
[(labels[idx], percentage2_5[idx].item()) for idx in indices2_5[0][:5]]
# Out:
# [('Rottweiler', 99.26301574707031),
#  ('black-and-tan coonhound', 0.3133784830570221),
#  ('Greater Swiss Mountain dog', 0.10885010659694672),
#  ('Doberman, Doberman pinscher', 0.0979495495557785),
#  ('EntleBucher', 0.09388595074415207)]

# %% [markdown]
# Computational Complexity and Number of Parameters

# %%
with torch.cuda.device(0):
  macs, params = get_model_complexity_info(mobilenet, (3, 224, 224), as_strings=True,
                                           print_per_layer_stat=True, verbose=True)
  print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
  print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# ...
# MobileNetV2(
#   3.505 M, 100.000% Params, 0.32 GMac, 100.000% MACs,
#   (features): Sequential(
#     2.224 M, 63.451% Params, 0.319 GMac, 99.600% MACs,
#     (0): ConvNormActivation(
#       0.001 M, 0.026% Params, 0.012 GMac, 3.760% MACs,
#       (0): Conv2d(0.001 M, 0.025% Params, 0.011 GMac, 3.384% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(0.0 M, 0.002% Params, 0.001 GMac, 0.251% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(0.0 M, 0.000% Params, 0.0 GMac, 0.125% MACs, inplace=True)
#     )
#     (1): InvertedResidual(
#       0.001 M, 0.026% Params, 0.012 GMac, 3.635% MACs,
#       (conv): Sequential(
#         0.001 M, 0.026% Params, 0.012 GMac, 3.635% MACs,
#         (0): ConvNormActivation(
#           0.0 M, 0.010% Params, 0.005 GMac, 1.504% MACs,
# ...
